# %%
#Set file path for current directory
import os
# %cd /content/drive/MyDrive/Colab Notebooks/CrewAI-Stock-Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ensure the tools folder exists
os.makedirs('tools', exist_ok=True)

# Create the __init__.py file in the tools folder
open(os.path.join('tools', '__init__.py'), 'a').close()

# %%
# Define API keys and stock ticker
os.environ['SERPER_API_KEY'] = "KEY"  # https://serper.dev/ (free tier)
os.environ['BROWSERLESS_API_KEY'] = "KEY" # https://www.browserless.io/ (free tier)
os.environ['SEC_API_API_KEY'] = "KEY"  # https://sec-api.io/ (free tier)
os.environ['OPENAI_API_KEY'] = "KEY"  # https://openai.com/

# %%
# For pyproject.toml, use Poetry (if specified)
# !pip install poetry
# !poetry install --no-root
# !pip install crewai==0.11.0 unstructured==0.10.25 pyowm==3.3.0 tools==0.1.9 wikipedia==1.4.0 yfinance==0.2.35 sec-api==1.0.17 tiktoken==0.5.2 faiss-cpu==1.7.4 python-dotenv==1.0.0 langchain-community==0.0.10 langchain-core==0.1.8 openai==1.7.1

# %%
# Run the main script
# !python main.py
